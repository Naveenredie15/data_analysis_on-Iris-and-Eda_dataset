# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from skimage import io

# %% [markdown]
# dataset link: https://i.pinimg.com/originals/c6/e7/df/c6e7dfb7c951eed5cb516b56a4751632.jpg

# %%
image = io.imread("https://p.turbosquid.com/ts-thumb/LF/IolaOR/pm/2022_mercedesbenz_cclass_00000white1200/jpg/1627994045/300x300/sharp_fit_q85/a5ceb962fb596418ee81dc3b59d03dfc8af92f97/2022_mercedesbenz_cclass_00000white1200.jpg")
image=image[50:250,:]

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x7FA64D02D4C0>

# %%
gray_filter = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_filter)
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x7FA640A6E0A0>

# %%
inverted_filter = cv2.bitwise_not(gray_filter)
cv2_imshow(inverted_filter)
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x7FA6731E9E80>

# %%
image_smoothing = cv2.GaussianBlur(inverted_filter, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x7FA640AD48E0>

# %%
def pencil_sketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = pencil_sketch(gray_filter, image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x7FA640AD4940>

# %% [markdown]
# CONCLUSION:
#
# Image is converted into a sketch using python.
